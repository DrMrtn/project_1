# %%
import chardet
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# source : https://ourworldindata.org/
# presentation : https://docs.google.com/presentation/d/1BQxe-5N6fNf0d5AIg_oVCUY--2dwBfMeGdirS6sQQUM/edit#slide=id.p

# %%
# small death table
death= {'2018':[9396, 6507, 3192, 48344, 1829, 3539],
        '2019':[9041, 6524, 3318, 47511, 1811, 3671],
        '2020':[9206, 5224, 3139, 45079, 1823, 3941]}
death = pd.DataFrame(death, index =['Germany','UK','Australia','USA','Netherlands','Spain']).reset_index()
death = death.rename(columns={'index':'country'})
death
# Out:
#        country   2018   2019   2020
# 0      Germany   9396   9041   9206
# 1           UK   6507   6524   5224
# 2    Australia   3192   3318   3139
# 3          USA  48344  47511  45079
# 4  Netherlands   1829   1811   1823
# 5        Spain   3539   3671   3941

# %%
death.to_csv('death_numbers.csv')

# %%
# # depression
# prev_depr = pd.read_csv('share-with-depression.csv')
# prev_depr = prev_depr.rename(columns={'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)':'prev_drep'})
# prev_depr = prev_depr.prev_drep
# prev_depr.shape

# # anxiety
# prev_anx = pd.read_csv('share-with-anxiety-disorders.csv')
# prev_anx = prev_anx.rename(columns={'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)': 'prev_anx'})
# # prev_anx = prev_anx.prev_anx
# prev_anx.shape

# # eating
# prev_eat = pd.read_csv('share-with-an-eating-disorder.csv')
# prev_eat = prev_eat.rename(columns={'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)': 'prev_eat'})
# prev_eat = prev_eat.prev_eat
# prev_eat.shape

# # bipolar
# prev_bi = pd.read_csv('share-with-bipolar-disorder.csv')
# prev_bi = prev_bi.rename(columns={'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)': 'prev_bi'})
# prev_bi = prev_bi.prev_bi
# prev_bi.shape

# # total
# prev_all = pd.read_csv('share-with-mental-and-substance-disorders.csv')
# prev_all = prev_all.rename(columns={'Prevalence - Mental disorders - Sex: Both - Age: Age-standardized (Percent)': 'prev_all'})
# prev_all.shape

# # merging
# prev_all_depr = pd.concat([prev_all,prev_depr],axis=1)
# prev_all_depr.dtypes
# prev_anx_sui_eat_bi = pd.concat([prev_anx,prev_sui,prev_sui,prev_eat,prev_bi],axis=1)
# prev_anx_sui_eat_bi.dtypes
# prev_all_depr.to_csv('prev_merged.csv',index=False)
# prev_anx_sui_eat_bi.to_csv('prev_anx_sui_eat_bi.csv',index=False)
# # saving
# prev_all_depr.to_csv('prev_merged.csv',index=False)
# prev_anx_sui_eat_bi.to_csv('prev_anx_sui_eat_bi.csv',index=False)

# %%
# suicide 
prev_sui = pd.read_csv('suicide-death-rates.csv')
prev_sui = prev_sui.rename(columns={'Deaths - Self-harm - Sex: Both - Age: Age-standardized (Rate)':'death_rate'})
prev_sui = prev_sui.death_rate
prev_sui.shape
# Out:
# (6840,)

# %%
# suicide 2
prev_sui_2 = pd.read_csv('suicide-rates-vs-prevalence-of-mental-and-substance-use-disorders.csv')
prev_sui_2
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 57202       Zimbabwe       ZWE  1988
# 57203       Zimbabwe       ZWE  1989
# 57204       Zimbabwe       ZWE  2020
# 57205       Zimbabwe       ZWE  2021
# 57206  Åland Islands       ALA  2015
#
#        Deaths - Self-harm - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                    NaN
# 1                                               8.277699
# 2                                               8.174310
# 3                                               8.139174
# 4                                               8.231295
# ...                                                  ...
# 57202                                                NaN
# ...

# %%
# test[test.Entity!='Vietnam'].sort_values('Prevalence', ascending=True).head(20)

# %%
prev_complete = pd.read_csv('prevalence-by-mental-and-substance-use-disorder.csv')
prev_complete = prev_complete.rename(columns={'Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)':'schizophrenia',
                                              'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)':'bipolar',
                                              'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)':'eating',
                                              'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)':'anxiety',
                                              'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)':'drugs',
                                              'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)':'depression',
                                              'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)':'alcohol'})

# %%
prev_complete = pd.concat([prev_complete,prev_sui],axis=1)
prev_complete = prev_complete.drop('Code',axis=1)
prev_complete
# Out:
#            Entity  Year  schizophrenia   bipolar    eating   anxiety  \
# 0     Afghanistan  1990       0.228979  0.721207  0.131001  4.835127
# 1     Afghanistan  1991       0.228120  0.719952  0.126395  4.821765
# 2     Afghanistan  1992       0.227328  0.718418  0.121832  4.801434
# 3     Afghanistan  1993       0.226468  0.717452  0.117942  4.789363
# 4     Afghanistan  1994       0.225567  0.717012  0.114547  4.784923
# ...           ...   ...            ...       ...       ...       ...
# 6835     Zimbabwe  2015       0.209359  0.560882  0.099610  3.315701
# 6836     Zimbabwe  2016       0.209979  0.561768  0.100821  3.324230
# 6837     Zimbabwe  2017       0.210631  0.562612  0.101671  3.330569
# 6838     Zimbabwe  2018       0.211237  0.563283  0.102398  3.317500
# 6839     Zimbabwe  2019       0.211969  0.563820  0.102902  3.283934
#
#          drugs  depression   alcohol  death_rate
# 0     0.454202    5.125291  0.444036    8.277699
# ...

# %%
# schizophrenia, bipolar, eating, anxiety, drugs, depression, alcohol = Prevalence-Sex: Both - Age: Age-standardized (Percent)
# death_rate: deaths per 100.000 people

# %%
prev_complete.alcohol.max()
# Out:
# 4.69869401548336

# %%
prev_complete.death_rate.mean()
# Out:
# 12.064283189832468

# %%
sns.heatmap(prev_complete.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# prev_complete[prev_complete.Entity=='Greenland']
# Out:
#          Entity  Year  schizophrenia   bipolar    eating   anxiety     drugs  \
# 2310  Greenland  1990       0.401731  0.667871  0.474378  5.123995  1.636429
# 2311  Greenland  1991       0.403911  0.668181  0.472481  5.132560  1.615851
# 2312  Greenland  1992       0.405796  0.668599  0.470215  5.140576  1.600060
# 2313  Greenland  1993       0.407400  0.668863  0.467973  5.144708  1.590254
# 2314  Greenland  1994       0.408523  0.669224  0.465693  5.147370  1.585346
# 2315  Greenland  1995       0.408991  0.669473  0.464239  5.151253  1.585089
# 2316  Greenland  1996       0.408896  0.669848  0.464612  5.155189  1.592295
# 2317  Greenland  1997       0.408489  0.669955  0.465366  5.161525  1.604576
# 2318  Greenland  1998       0.408026  0.670087  0.465844  5.166721  1.618442
# 2319  Greenland  1999       0.407677  0.670293  0.466122  5.169193  1.634063
# 2320  Greenland  2000       0.407609  0.670537  0.465962  5.169725  1.645123
# ...

# %%
# prev_complete.to_csv('prev_complete.csv',index=False)

# %%
# code for sql

# %%
# test code
# test.pivot_table(index='Entity',
#                  columns='Year',
#                  values='Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)')
# test[test.Entity!='Vietnam'].sort_values('Prevalence', ascending=True).head(20)
